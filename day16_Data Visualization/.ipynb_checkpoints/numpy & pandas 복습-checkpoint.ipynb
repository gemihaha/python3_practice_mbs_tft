# %%
import numpy as np

# %%
a = np.eye(2) # [[1., 0.],[0., 1.]]
type(a[0,0])
# Out:
# numpy.float64

# %%
b = np.random.random((3,5,3))

# %%
b
# Out:
# array([[[0.25575403, 0.75188004, 0.913565  ],
#         [0.08729804, 0.77179539, 0.57674896],
#         [0.92556766, 0.2559444 , 0.84745518],
#         [0.55640496, 0.22153955, 0.34897903],
#         [0.65717398, 0.79565176, 0.17728942]],
#
#        [[0.50339968, 0.1843768 , 0.54520708],
#         [0.06921689, 0.86010223, 0.98769675],
#         [0.71698593, 0.63077602, 0.3987958 ],
#         [0.00467361, 0.31177997, 0.60058924],
#         [0.98379703, 0.29841159, 0.89724446]],
#
#        [[0.24685877, 0.37748905, 0.88048944],
#         [0.30844504, 0.84299447, 0.63361083],
#         [0.943278  , 0.68085792, 0.42633516],
#         [0.07246466, 0.92524427, 0.53296977],
#         [0.91026605, 0.83163296, 0.83063794]]])

# %%
b[1, 3, 2]
# Out:
# 0.600589235861773

# %%
b[1]
# Out:
# array([[0.50339968, 0.1843768 , 0.54520708],
#        [0.06921689, 0.86010223, 0.98769675],
#        [0.71698593, 0.63077602, 0.3987958 ],
#        [0.00467361, 0.31177997, 0.60058924],
#        [0.98379703, 0.29841159, 0.89724446]])

# %%
b[1, 3].shape
# Out:
# (3,)

# %%
a = np.random.random((3,4))

# %%
a
# Out:
# array([[0.11082722, 0.00761203, 0.720193  , 0.7131993 ],
#        [0.37185865, 0.82953259, 0.4165274 , 0.89906815],
#        [0.21013153, 0.68170111, 0.54124629, 0.48194264]])

# %%
b = a[1:, 2]
b
# Out:
# array([0.4165274 , 0.54124629])

# %%
b.shape
# Out:
# (2,)

# %%
b[0] = 2

# %%
b
# Out:
# array([2.        , 0.54124629])

# %%
a   # b 의 값을 수정하면 a 의 값도 변경됨 !!!
# Out:
# array([[0.11082722, 0.00761203, 0.720193  , 0.7131993 ],
#        [0.37185865, 0.82953259, 2.        , 0.89906815],
#        [0.21013153, 0.68170111, 0.54124629, 0.48194264]])

# %%
# Advanced indexing
a[[1, 2, 2], [0, 1 ,1]]
# Out:
# array([0.37185865, 0.68170111, 0.68170111])

# %%
c = a[[1, 2, 2], [0, 1, 1]]

# %%
c
# Out:
# array([0.37185865, 0.68170111, 0.68170111])

# %%
c[2] = 8

# %%
c
# Out:
# array([0.37185865, 0.68170111, 8.        ])

# %%
a
# Out:
# array([[0.11082722, 0.00761203, 0.720193  , 0.7131993 ],
#        [0.37185865, 0.82953259, 2.        , 0.89906815],
#        [0.21013153, 0.68170111, 0.54124629, 0.48194264]])

# %% [markdown]
# ### Numpy Array math

# %%
x = np.array([[1,2],[3,4]], dtype=np.float64)
y = np.array([[5,6],[7,8]], dtype=np.float64)

# %%
print(x+y)
# Out:
# [[ 6.  8.]
#  [10. 12.]]

# %%
print(np.multiply(x,y))
# Out:
# [[ 5. 12.]
#  [21. 32.]]

# %%
print(np.dot(x,y))
# Out:
# [[19. 22.]
#  [43. 50.]]

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df.shape
# Out:
# (150, 4)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
# sepal length (cm)    150 non-null float64
# sepal width (cm)     150 non-null float64
# petal length (cm)    150 non-null float64
# petal width (cm)     150 non-null float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
df.count()
# Out:
# sepal length (cm)    150
# sepal width (cm)     150
# petal length (cm)    150
# petal width (cm)     150
# dtype: int64

# %%
df.sum()
# Out:
# sepal length (cm)    876.5
# sepal width (cm)     458.6
# petal length (cm)    563.7
# petal width (cm)     179.9
# dtype: float64

# %%
df.cumsum()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                 10.0               6.5                2.8               0.4
# 2                 14.7               9.7                4.1               0.6
# 3                 19.3              12.8                5.6               0.8
# 4                 24.3              16.4                7.0               1.0
# 5                 29.7              20.3                8.7               1.4
# 6                 34.3              23.7               10.1               1.7
# 7                 39.3              27.1               11.6               1.9
# 8                 43.7              30.0               13.0               2.1
# 9                 48.6              33.1               14.5               2.2
# 10                54.0              36.8               16.0               2.4
# 11                58.8              40.2               17.6               2.6
# 12                63.6              43.2               19.0               2.7
# 13                67.9              46.2               20.1               2.8
# 14                73.7              50.2               21.3               3.0
# 15                79.4              54.6               22.8               3.4
# 16                84.8              58.5               24.1               3.8
# 17                89.9              62.0               25.5               4.1
# 18                95.6              65.8               27.2               4.4
# 19               100.7              69.6               28.7               4.7
# 20               106.1              73.0               30.4               4.9
# 21               111.2              76.7               31.9               5.3
# 22               115.8              80.3               32.9               5.5
# 23               120.9              83.6               34.6               6.0
# 24               125.7              87.0               36.5               6.2
# 25               130.7              90.0               38.1               6.4
# 26               135.7              93.4               39.7               6.8
# 27               140.9              96.9               41.2               7.0
# 28               146.1             100.3               42.6               7.2
# 29               150.8             103.5               44.2               7.4
# ..                 ...               ...                ...               ...
# 120              685.2             371.5              404.9             121.8
# 121              690.8             374.3              409.8             123.8
# 122              698.5             377.1              416.5             125.8
# 123              704.8             379.8              421.4             127.6
# 124              711.5             383.1              427.1             129.7
# 125              718.7             386.3              433.1             131.5
# 126              724.9             389.1              437.9             133.3
# 127              731.0             392.1              442.8             135.1
# 128              737.4             394.9              448.4             137.2
# 129              744.6             397.9              454.2             138.8
# 130              752.0             400.7              460.3             140.7
# 131              759.9             404.5              466.7             142.7
# 132              766.3             407.3              472.3             144.9
# 133              772.6             410.1              477.4             146.4
# 134              778.7             412.7              483.0             147.8
# 135              786.4             415.7              489.1             150.1
# 136              792.7             419.1              494.7             152.5
# 137              799.1             422.2              500.2             154.3
# 138              805.1             425.2              505.0             156.1
# 139              812.0             428.3              510.4             158.2
# 140              818.7             431.4              516.0             160.6
# 141              825.6             434.5              521.1             162.9
# 142              831.4             437.2              526.2             164.8
# 143              838.2             440.4              532.1             167.1
# 144              844.9             443.7              537.8             169.6
# 145              851.6             446.7              543.0             171.9
# 146              857.9             449.2              548.0             173.8
# 147              864.4             452.2              553.2             175.8
# 148              870.6             455.6              558.6             178.1
# 149              876.5             458.6              563.7             179.9
#
# [150 rows x 4 columns]

# %%
df.min()
# Out:
# sepal length (cm)    4.3
# sepal width (cm)     2.0
# petal length (cm)    1.0
# petal width (cm)     0.1
# dtype: float64

# %%
df.max()
# Out:
# sepal length (cm)    7.9
# sepal width (cm)     4.4
# petal length (cm)    6.9
# petal width (cm)     2.5
# dtype: float64

# %%
df.idxmin()
# Out:
# sepal length (cm)    13
# sepal width (cm)     60
# petal length (cm)    22
# petal width (cm)      9
# dtype: int64

# %%
df.idxmax()
# Out:
# sepal length (cm)    131
# sepal width (cm)      15
# petal length (cm)    118
# petal width (cm)     100
# dtype: int64

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
df.mean()
# Out:
# sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# dtype: float64

# %%
df.median()
# Out:
# sepal length (cm)    5.80
# sepal width (cm)     3.00
# petal length (cm)    4.35
# petal width (cm)     1.30
# dtype: float64

# %%
df2 = df.set_index('sepal length (cm)')
df3 = df2.set_index('sepal width (cm)')

# %%
df3.reset_index()
# Out:
#      sepal width (cm)  petal length (cm)  petal width (cm)
# 0                 3.5                1.4               0.2
# 1                 3.0                1.4               0.2
# 2                 3.2                1.3               0.2
# 3                 3.1                1.5               0.2
# 4                 3.6                1.4               0.2
# 5                 3.9                1.7               0.4
# 6                 3.4                1.4               0.3
# 7                 3.4                1.5               0.2
# 8                 2.9                1.4               0.2
# 9                 3.1                1.5               0.1
# 10                3.7                1.5               0.2
# 11                3.4                1.6               0.2
# 12                3.0                1.4               0.1
# 13                3.0                1.1               0.1
# 14                4.0                1.2               0.2
# 15                4.4                1.5               0.4
# 16                3.9                1.3               0.4
# 17                3.5                1.4               0.3
# 18                3.8                1.7               0.3
# 19                3.8                1.5               0.3
# 20                3.4                1.7               0.2
# 21                3.7                1.5               0.4
# 22                3.6                1.0               0.2
# 23                3.3                1.7               0.5
# 24                3.4                1.9               0.2
# 25                3.0                1.6               0.2
# 26                3.4                1.6               0.4
# 27                3.5                1.5               0.2
# 28                3.4                1.4               0.2
# 29                3.2                1.6               0.2
# ..                ...                ...               ...
# 120               3.2                5.7               2.3
# 121               2.8                4.9               2.0
# 122               2.8                6.7               2.0
# 123               2.7                4.9               1.8
# 124               3.3                5.7               2.1
# 125               3.2                6.0               1.8
# 126               2.8                4.8               1.8
# 127               3.0                4.9               1.8
# 128               2.8                5.6               2.1
# 129               3.0                5.8               1.6
# 130               2.8                6.1               1.9
# 131               3.8                6.4               2.0
# 132               2.8                5.6               2.2
# 133               2.8                5.1               1.5
# 134               2.6                5.6               1.4
# 135               3.0                6.1               2.3
# 136               3.4                5.6               2.4
# 137               3.1                5.5               1.8
# 138               3.0                4.8               1.8
# 139               3.1                5.4               2.1
# 140               3.1                5.6               2.4
# 141               3.1                5.1               2.3
# 142               2.7                5.1               1.9
# 143               3.2                5.9               2.3
# 144               3.3                5.7               2.5
# 145               3.0                5.2               2.3
# 146               2.5                5.0               1.9
# 147               3.0                5.2               2.0
# 148               3.4                5.4               2.3
# 149               3.0                5.1               1.8
#
# [150 rows x 3 columns]

# %%
df.rename(index=str,
    columns = {'sepal width (cm)' : 'sp',
                     'petal length (cm)' : 'pl',
                   'petal width (cm)' : 'pw'})
# Out:
#      sepal length (cm)   sp   pl   pw
# 0                  5.1  3.5  1.4  0.2
# 1                  4.9  3.0  1.4  0.2
# 2                  4.7  3.2  1.3  0.2
# 3                  4.6  3.1  1.5  0.2
# 4                  5.0  3.6  1.4  0.2
# 5                  5.4  3.9  1.7  0.4
# 6                  4.6  3.4  1.4  0.3
# 7                  5.0  3.4  1.5  0.2
# 8                  4.4  2.9  1.4  0.2
# 9                  4.9  3.1  1.5  0.1
# 10                 5.4  3.7  1.5  0.2
# 11                 4.8  3.4  1.6  0.2
# 12                 4.8  3.0  1.4  0.1
# 13                 4.3  3.0  1.1  0.1
# 14                 5.8  4.0  1.2  0.2
# 15                 5.7  4.4  1.5  0.4
# 16                 5.4  3.9  1.3  0.4
# 17                 5.1  3.5  1.4  0.3
# 18                 5.7  3.8  1.7  0.3
# 19                 5.1  3.8  1.5  0.3
# 20                 5.4  3.4  1.7  0.2
# 21                 5.1  3.7  1.5  0.4
# 22                 4.6  3.6  1.0  0.2
# 23                 5.1  3.3  1.7  0.5
# 24                 4.8  3.4  1.9  0.2
# 25                 5.0  3.0  1.6  0.2
# 26                 5.0  3.4  1.6  0.4
# 27                 5.2  3.5  1.5  0.2
# 28                 5.2  3.4  1.4  0.2
# 29                 4.7  3.2  1.6  0.2
# ..                 ...  ...  ...  ...
# 120                6.9  3.2  5.7  2.3
# 121                5.6  2.8  4.9  2.0
# 122                7.7  2.8  6.7  2.0
# 123                6.3  2.7  4.9  1.8
# 124                6.7  3.3  5.7  2.1
# 125                7.2  3.2  6.0  1.8
# 126                6.2  2.8  4.8  1.8
# 127                6.1  3.0  4.9  1.8
# 128                6.4  2.8  5.6  2.1
# 129                7.2  3.0  5.8  1.6
# 130                7.4  2.8  6.1  1.9
# 131                7.9  3.8  6.4  2.0
# 132                6.4  2.8  5.6  2.2
# 133                6.3  2.8  5.1  1.5
# 134                6.1  2.6  5.6  1.4
# 135                7.7  3.0  6.1  2.3
# 136                6.3  3.4  5.6  2.4
# 137                6.4  3.1  5.5  1.8
# 138                6.0  3.0  4.8  1.8
# 139                6.9  3.1  5.4  2.1
# 140                6.7  3.1  5.6  2.4
# 141                6.9  3.1  5.1  2.3
# 142                5.8  2.7  5.1  1.9
# 143                6.8  3.2  5.9  2.3
# 144                6.7  3.3  5.7  2.5
# 145                6.7  3.0  5.2  2.3
# 146                6.3  2.5  5.0  1.9
# 147                6.5  3.0  5.2  2.0
# 148                6.2  3.4  5.4  2.3
# 149                5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
f = lambda x : x*2
df.apply(f)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                 10.2               7.0                2.8               0.4
# 1                  9.8               6.0                2.8               0.4
# 2                  9.4               6.4                2.6               0.4
# 3                  9.2               6.2                3.0               0.4
# 4                 10.0               7.2                2.8               0.4
# 5                 10.8               7.8                3.4               0.8
# 6                  9.2               6.8                2.8               0.6
# 7                 10.0               6.8                3.0               0.4
# 8                  8.8               5.8                2.8               0.4
# 9                  9.8               6.2                3.0               0.2
# 10                10.8               7.4                3.0               0.4
# 11                 9.6               6.8                3.2               0.4
# 12                 9.6               6.0                2.8               0.2
# 13                 8.6               6.0                2.2               0.2
# 14                11.6               8.0                2.4               0.4
# 15                11.4               8.8                3.0               0.8
# 16                10.8               7.8                2.6               0.8
# 17                10.2               7.0                2.8               0.6
# 18                11.4               7.6                3.4               0.6
# 19                10.2               7.6                3.0               0.6
# 20                10.8               6.8                3.4               0.4
# 21                10.2               7.4                3.0               0.8
# 22                 9.2               7.2                2.0               0.4
# 23                10.2               6.6                3.4               1.0
# 24                 9.6               6.8                3.8               0.4
# 25                10.0               6.0                3.2               0.4
# 26                10.0               6.8                3.2               0.8
# 27                10.4               7.0                3.0               0.4
# 28                10.4               6.8                2.8               0.4
# 29                 9.4               6.4                3.2               0.4
# ..                 ...               ...                ...               ...
# 120               13.8               6.4               11.4               4.6
# 121               11.2               5.6                9.8               4.0
# 122               15.4               5.6               13.4               4.0
# 123               12.6               5.4                9.8               3.6
# 124               13.4               6.6               11.4               4.2
# 125               14.4               6.4               12.0               3.6
# 126               12.4               5.6                9.6               3.6
# 127               12.2               6.0                9.8               3.6
# 128               12.8               5.6               11.2               4.2
# 129               14.4               6.0               11.6               3.2
# 130               14.8               5.6               12.2               3.8
# 131               15.8               7.6               12.8               4.0
# 132               12.8               5.6               11.2               4.4
# 133               12.6               5.6               10.2               3.0
# 134               12.2               5.2               11.2               2.8
# 135               15.4               6.0               12.2               4.6
# 136               12.6               6.8               11.2               4.8
# 137               12.8               6.2               11.0               3.6
# 138               12.0               6.0                9.6               3.6
# 139               13.8               6.2               10.8               4.2
# 140               13.4               6.2               11.2               4.8
# 141               13.8               6.2               10.2               4.6
# 142               11.6               5.4               10.2               3.8
# 143               13.6               6.4               11.8               4.6
# 144               13.4               6.6               11.4               5.0
# 145               13.4               6.0               10.4               4.6
# 146               12.6               5.0               10.0               3.8
# 147               13.0               6.0               10.4               4.0
# 148               12.4               6.8               10.8               4.6
# 149               11.8               6.0               10.2               3.6
#
# [150 rows x 4 columns]

# %%
df.sort_values(by='sepal length (cm)')
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 13                 4.3               3.0                1.1               0.1
# 42                 4.4               3.2                1.3               0.2
# 38                 4.4               3.0                1.3               0.2
# 8                  4.4               2.9                1.4               0.2
# 41                 4.5               2.3                1.3               0.3
# 22                 4.6               3.6                1.0               0.2
# 3                  4.6               3.1                1.5               0.2
# 6                  4.6               3.4                1.4               0.3
# 47                 4.6               3.2                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 29                 4.7               3.2                1.6               0.2
# 12                 4.8               3.0                1.4               0.1
# 45                 4.8               3.0                1.4               0.3
# 24                 4.8               3.4                1.9               0.2
# 11                 4.8               3.4                1.6               0.2
# 30                 4.8               3.1                1.6               0.2
# 57                 4.9               2.4                3.3               1.0
# 106                4.9               2.5                4.5               1.7
# 34                 4.9               3.1                1.5               0.2
# 9                  4.9               3.1                1.5               0.1
# 37                 4.9               3.6                1.4               0.1
# 1                  4.9               3.0                1.4               0.2
# 40                 5.0               3.5                1.3               0.3
# 26                 5.0               3.4                1.6               0.4
# 49                 5.0               3.3                1.4               0.2
# 35                 5.0               3.2                1.2               0.2
# 43                 5.0               3.5                1.6               0.6
# 60                 5.0               2.0                3.5               1.0
# 7                  5.0               3.4                1.5               0.2
# 93                 5.0               2.3                3.3               1.0
# ..                 ...               ...                ...               ...
# 58                 6.6               2.9                4.6               1.3
# 75                 6.6               3.0                4.4               1.4
# 86                 6.7               3.1                4.7               1.5
# 140                6.7               3.1                5.6               2.4
# 108                6.7               2.5                5.8               1.8
# 77                 6.7               3.0                5.0               1.7
# 65                 6.7               3.1                4.4               1.4
# 144                6.7               3.3                5.7               2.5
# 145                6.7               3.0                5.2               2.3
# 124                6.7               3.3                5.7               2.1
# 143                6.8               3.2                5.9               2.3
# 76                 6.8               2.8                4.8               1.4
# 112                6.8               3.0                5.5               2.1
# 139                6.9               3.1                5.4               2.1
# 141                6.9               3.1                5.1               2.3
# 52                 6.9               3.1                4.9               1.5
# 120                6.9               3.2                5.7               2.3
# 50                 7.0               3.2                4.7               1.4
# 102                7.1               3.0                5.9               2.1
# 129                7.2               3.0                5.8               1.6
# 125                7.2               3.2                6.0               1.8
# 109                7.2               3.6                6.1               2.5
# 107                7.3               2.9                6.3               1.8
# 130                7.4               2.8                6.1               1.9
# 105                7.6               3.0                6.6               2.1
# 122                7.7               2.8                6.7               2.0
# 118                7.7               2.6                6.9               2.3
# 117                7.7               3.8                6.7               2.2
# 135                7.7               3.0                6.1               2.3
# 131                7.9               3.8                6.4               2.0
#
# [150 rows x 4 columns]

# %%
df['sepal length (cm)'].value_counts()
# Out:
# 5.0    10
# 6.3     9
# 5.1     9
# 6.7     8
# 5.7     8
# 5.5     7
# 5.8     7
# 6.4     7
# 6.0     6
# 4.9     6
# 6.1     6
# 5.4     6
# 5.6     6
# 6.5     5
# 4.8     5
# 7.7     4
# 6.9     4
# 5.2     4
# 6.2     4
# 4.6     4
# 7.2     3
# 6.8     3
# 4.4     3
# 5.9     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 4.3     1
# 7.9     1
# 7.3     1
# 7.0     1
# 4.5     1
# 5.3     1
# 7.1     1
# Name: sepal length (cm), dtype: int64
