# %% [markdown]
# # Statistical Data Analysis Using ML

# %% [markdown]
# ### 데이터 로드

# %%
import pandas as pd
df = pd.read_csv('data/Advertising.csv')

# %%
# 데이터 확인
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# 5      8.7   48.9       75.0    7.2
# 6     57.5   32.8       23.5   11.8
# 7    120.2   19.6       11.6   13.2
# 8      8.6    2.1        1.0    4.8
# 9    199.8    2.6       21.2   10.6
# 10    66.1    5.8       24.2    8.6
# 11   214.7   24.0        4.0   17.4
# 12    23.8   35.1       65.9    9.2
# 13    97.5    7.6        7.2    9.7
# 14   204.1   32.9       46.0   19.0
# 15   195.4   47.7       52.9   22.4
# 16    67.8   36.6      114.0   12.5
# 17   281.4   39.6       55.8   24.4
# 18    69.2   20.5       18.3   11.3
# 19   147.3   23.9       19.1   14.6
# 20   218.4   27.7       53.4   18.0
# 21   237.4    5.1       23.5   12.5
# 22    13.2   15.9       49.6    5.6
# 23   228.3   16.9       26.2   15.5
# 24    62.3   12.6       18.3    9.7
# 25   262.9    3.5       19.5   12.0
# 26   142.9   29.3       12.6   15.0
# 27   240.1   16.7       22.9   15.9
# 28   248.8   27.1       22.9   18.9
# 29    70.6   16.0       40.8   10.5
# ..     ...    ...        ...    ...
# 170   50.0   11.6       18.4    8.4
# 171  164.5   20.9       47.4   14.5
# 172   19.6   20.1       17.0    7.6
# 173  168.4    7.1       12.8   11.7
# 174  222.4    3.4       13.1   11.5
# 175  276.9   48.9       41.8   27.0
# 176  248.4   30.2       20.3   20.2
# 177  170.2    7.8       35.2   11.7
# 178  276.7    2.3       23.7   11.8
# 179  165.6   10.0       17.6   12.6
# 180  156.6    2.6        8.3   10.5
# 181  218.5    5.4       27.4   12.2
# 182   56.2    5.7       29.7    8.7
# 183  287.6   43.0       71.8   26.2
# 184  253.8   21.3       30.0   17.6
# 185  205.0   45.1       19.6   22.6
# 186  139.5    2.1       26.6   10.3
# 187  191.1   28.7       18.2   17.3
# 188  286.0   13.9        3.7   15.9
# 189   18.7   12.1       23.4    6.7
# 190   39.5   41.1        5.8   10.8
# 191   75.5   10.8        6.0    9.9
# 192   17.2    4.1       31.6    5.9
# 193  166.8   42.0        3.6   19.6
# 194  149.7   35.6        6.0   17.3
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %% [markdown]
# ### Train/Test Set 분할
#
# 보통은 실제 데이터를 바탕으로 Train을 하고, 새로운 데이터를 기반으로 Test를 하지만, 본 연습에서는 주어진 데이터를 Train 데이터와 Test 데이터로 나누어 분석하고자 한다. 이를 위해 Scikit-Learn이 제공하는 train_test_split 모듈을 사용한다.

# %%
from sklearn.model_selection import train_test_split

#아래에 코드 작성
features = ['TV','radio','newspaper']
X_train, X_test, y_train, y_test = train_test_split(df[features], df['sales'], random_state=2)


print(X_train)
print(y_train)
# Out:
#         TV  radio  newspaper
# 159  131.7   18.4       34.6
# 100  222.4    4.3       49.8
# 11   214.7   24.0        4.0
# 187  191.1   28.7       18.2
# 24    62.3   12.6       18.3
# 89   109.8   47.8       51.4
# 66    31.5   24.6        2.2
# 8      8.6    2.1        1.0
# 172   19.6   20.1       17.0
# 175  276.9   48.9       41.8
# 28   248.8   27.1       22.9
# 133  219.8   33.5       45.1
# 94   107.4   14.0       10.9
# 42   293.6   27.7        1.8
# 169  284.3   10.6        6.4
# 82    75.3   20.3       32.5
# 184  253.8   21.3       30.0
# 106   25.0   11.0       29.7
# 108   13.1    0.4       25.6
# 143  104.6    5.7       34.4
# 180  156.6    2.6        8.3
# 166   17.9   37.6       21.6
# 146  240.1    7.3        8.7
# 79   116.0    7.7       23.1
# 1     44.5   39.3       45.1
# 119   19.4   16.0       22.3
# 192   17.2    4.1       31.6
# 149   44.7   25.8       20.6
# 160  172.5   18.1       30.7
# 188  286.0   13.9        3.7
# ..     ...    ...        ...
# 183  287.6   43.0       71.8
# 58   210.8   49.6       37.7
# 33   265.6   20.0        0.3
# 38    43.1   26.7       35.1
# 103  187.9   17.2       17.9
# 51   100.4    9.6        3.6
# 107   90.4    0.3       23.2
# 170   50.0   11.6       18.4
# 4    180.8   10.8       58.4
# 102  280.2   10.1       21.4
# 167  206.8    5.2       19.4
# 37    74.7   49.4       45.7
# 116  139.2   14.3       25.6
# 124  229.5   32.3       74.2
# 148   38.0   40.3       11.9
# 31   112.9   17.4       38.6
# 63   102.7   29.6        8.4
# 47   239.9   41.5       18.5
# 194  149.7   35.6        6.0
# 95   163.3   31.6       52.9
# 177  170.2    7.8       35.2
# 162  188.4   18.1       25.6
# 7    120.2   19.6       11.6
# 104  238.2   34.3        5.3
# 75    16.9   43.7       89.4
# 43   206.9    8.4       26.4
# 22    13.2   15.9       49.6
# 72    26.8   33.0       19.3
# 15   195.4   47.7       52.9
# 168  215.4   23.6       57.6
#
# [150 rows x 3 columns]
# 159    12.9
# 100    11.7
# 11     17.4
# 187    17.3
# 24      9.7
# 89     16.7
# 66      9.5
# 8       4.8
# 172     7.6
# 175    27.0
# 28     18.9
# 133    19.6
# 94     11.5
# 42     20.7
# 169    15.0
# 82     11.3
# 184    17.6
# 106     7.2
# 108     5.3
# 143    10.4
# 180    10.5
# 166     8.0
# 146    13.2
# 79     11.0
# 1      10.4
# 119     6.6
# 192     5.9
# 149    10.1
# 160    14.4
# 188    15.9
#        ...
# 183    26.2
# 58     23.8
# 33     17.4
# 38     10.1
# 103    14.7
# 51     10.7
# 107     8.7
# 170     8.4
# 4      12.9
# 102    14.8
# 167    12.2
# 37     14.7
# 116    12.2
# 124    19.7
# 148    10.9
# 31     11.9
# 63     14.0
# 47     23.2
# 194    17.3
# 95     16.9
# 177    11.7
# 162    14.9
# 7      13.2
# 104    20.7
# 75      8.7
# 43     12.9
# 22      5.6
# 72      8.8
# 15     22.4
# 168    17.1
# Name: sales, Length: 150, dtype: float64

# %% [markdown]
# ### Linear regression

# %% [markdown]
# #### Linear regression 수행

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from matplotlib import pyplot as plt

# %%
#아래에 코드 작성
lm = linear_model.LinearRegression()
lm.fit(X_train, y_train)
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lm.predict(X_train)
# Out:
# array([12.69039858, 14.2899291 , 17.34219651, 17.19716031,  8.4063316 ,
#        17.15922083,  9.13481103,  3.96878995,  7.83773776, 24.8961722 ,
#        19.54235567, 19.50007622, 10.67482297, 21.58861882, 18.05497517,
#        10.47090324, 18.7387533 ,  6.47309535,  3.97289741,  9.13374846,
#        10.80609079, 10.98742632, 15.45612484,  9.96600613, 12.61178088,
#         7.10156738,  4.86386693, 10.0366976 , 14.46828091, 18.72439957,
#        23.39733303, 23.34159827, 14.69404283, 12.6120828 , 17.00632047,
#        20.86416548, 17.24250898, 10.33199905, 24.3102052 , 16.00946304,
#        18.41163411, 10.68489584, 15.64624055, 19.44424855, 13.9402933 ,
#        21.85433827, 15.61577398, 23.4599595 , 18.19236966, 14.21308301,
#        15.46622562,  6.8686854 , 19.62580755,  8.61954913, 21.58344937,
#        10.43699531, 14.99767726, 21.53248204, 13.48606411, 16.4845852 ,
#         4.91095006, 17.16883348, 14.71722079, 12.95016055, 17.43437738,
#        12.53672152, 13.85826838, 10.44024332,  8.39634805, 15.93447599,
#        10.22054464, 20.90351979, 10.16654471, 15.52255034, 23.7400541 ,
#         9.42355809, 11.22263016, 14.02894706, 23.11124023, 14.98403794,
#        19.04467127,  8.28630176,  8.8559794 , 14.33531389, 11.76053186,
#        18.00094924,  6.07935346,  7.8200195 , 16.60245569,  9.97745977,
#         4.82365726, 18.40262901, 15.09556879,  8.00875501,  5.66241857,
#        12.81967639, 14.60536977, 15.1889603 , 18.21166688, 10.24452424,
#         6.86826103, 18.63487018,  9.94172715,  5.52635671, 24.04652959,
#        11.53741957, 20.5820758 ,  8.53389836, 10.02181351,  8.56295639,
#        12.97619631, 20.82316961, 11.64704973, 20.83838281,  8.2458775 ,
#         6.36033186,  9.23326799, 12.19843756, 21.18817172, 12.21009481,
#        24.43651853, 22.00783011, 18.90124632, 10.19469404, 14.94389335,
#         9.51819474,  7.44969463,  7.66571311, 13.63287797, 17.84537131,
#        13.60954124, 15.8345323 , 12.23868473, 19.85201746, 12.34976436,
#        11.67263631, 13.30820528, 21.75680015, 16.52823126, 16.62474416,
#        12.49741579, 15.16633129, 12.2844514 , 20.30087589, 12.36672177,
#        14.23201978,  6.92571704, 10.53796393, 21.03013745, 17.54348478])

# %% [markdown]
# #### 통계값 계산

# %%
# The coefficients
print('Coefficients : {}'.format(lm.coef_))
# The mean squared error
print("Mean squared error : {}".format(mean_squared_error(y_train, lm.predict(X_train))))
# Explained variance score: 1 is perfect prediction
print('R^2 : {}'.format(r2_score(y_train, lm.predict(X_train))))
# Accuracy
print("Training set score: {}".format(lm.score(X_train, y_train)))
print("Test set score: {}".format(lm.score(X_test, y_test)))
# Out:
# Coefficients : [0.04535562 0.18319738 0.00453019]
# Mean squared error : 1.9224982640735342
# R^2 : 0.9322395888715463
# Training set score: 0.9322395888715463
# Test set score: 0.7558194773721318

# %% [markdown]
# #### 전체 판매량 재예측 및 시각화
#
# 학습된 lm 모델을 이용하여 전체 데이터를 다시 predict

# %%
#아래에 코드 작성
X = df[features]
X
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# 5      8.7   48.9       75.0
# 6     57.5   32.8       23.5
# 7    120.2   19.6       11.6
# 8      8.6    2.1        1.0
# 9    199.8    2.6       21.2
# 10    66.1    5.8       24.2
# 11   214.7   24.0        4.0
# 12    23.8   35.1       65.9
# 13    97.5    7.6        7.2
# 14   204.1   32.9       46.0
# 15   195.4   47.7       52.9
# 16    67.8   36.6      114.0
# 17   281.4   39.6       55.8
# 18    69.2   20.5       18.3
# 19   147.3   23.9       19.1
# 20   218.4   27.7       53.4
# 21   237.4    5.1       23.5
# 22    13.2   15.9       49.6
# 23   228.3   16.9       26.2
# 24    62.3   12.6       18.3
# 25   262.9    3.5       19.5
# 26   142.9   29.3       12.6
# 27   240.1   16.7       22.9
# 28   248.8   27.1       22.9
# 29    70.6   16.0       40.8
# ..     ...    ...        ...
# 170   50.0   11.6       18.4
# 171  164.5   20.9       47.4
# 172   19.6   20.1       17.0
# 173  168.4    7.1       12.8
# 174  222.4    3.4       13.1
# 175  276.9   48.9       41.8
# 176  248.4   30.2       20.3
# 177  170.2    7.8       35.2
# 178  276.7    2.3       23.7
# 179  165.6   10.0       17.6
# 180  156.6    2.6        8.3
# 181  218.5    5.4       27.4
# 182   56.2    5.7       29.7
# 183  287.6   43.0       71.8
# 184  253.8   21.3       30.0
# 185  205.0   45.1       19.6
# 186  139.5    2.1       26.6
# 187  191.1   28.7       18.2
# 188  286.0   13.9        3.7
# 189   18.7   12.1       23.4
# 190   39.5   41.1        5.8
# 191   75.5   10.8        6.0
# 192   17.2    4.1       31.6
# 193  166.8   42.0        3.6
# 194  149.7   35.6        6.0
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %% [markdown]
# sales와 predict 그래프 그리기

# %%
#아래에 코드 작성
pred = lm.predict(X)
pred
# Out:
# array([20.86416548, 12.61178088, 12.69230584, 17.89193155, 13.63287797,
#        12.88219732, 11.91276879, 12.2844514 ,  3.96878995, 12.82389305,
#         7.35966887, 17.34219651, 10.99771852,  9.03657736, 18.68215173,
#        21.03013745, 13.48606411, 23.4599595 , 10.16654471, 14.33531389,
#        18.41163411, 14.99767726,  6.92571704, 16.75890177,  8.4063316 ,
#        15.84300898, 15.09556879, 17.24250898, 19.54235567,  9.50758367,
#        21.85433827, 11.67263631,  8.00875501, 18.90124632,  7.8200195 ,
#        17.16398154, 23.34159827, 15.8345323 , 10.19469404, 20.5820758 ,
#        16.60245569, 17.51154272, 21.58861882, 14.23201978,  9.23224307,
#        15.39589817,  9.23326799, 21.75680015, 16.61485902,  8.53389836,
#        12.97619631,  9.51819474, 20.82316961, 20.20106455, 20.452523  ,
#        21.53248204,  8.8559794 , 12.95951332, 22.00783011, 18.19236966,
#         6.07935346, 23.11124023, 17.00632047, 13.30820528, 17.1073793 ,
#         8.02683754,  9.13481103, 12.21009481, 19.04467127, 21.18817172,
#        18.00094924, 10.93286367, 10.53796393, 10.24452424, 17.43437738,
#        12.36672177,  4.82365726, 13.9402933 ,  8.95459287,  9.96600613,
#        11.64704973, 14.98403794, 10.47090324, 14.60536977, 20.90351979,
#        15.62065818, 11.76053186, 15.93447599, 12.19843756, 17.15922083,
#        10.22054464,  4.91095006, 19.46779909, 21.58344937, 10.67482297,
#        16.62474416, 12.81967639, 15.52255034, 24.3102052 , 17.16883348,
#        14.2899291 , 23.7400541 , 17.84537131, 14.94389335, 20.30087589,
#        18.21166688,  6.47309535,  7.44969463,  3.97289741, 19.72623794,
#        15.1889603 , 21.21854132, 13.99058152, 16.51836403, 15.46622562,
#        13.24634355, 12.23868473,  6.86826103, 16.00946304,  7.10156738,
#        14.71722079,  8.2458775 , 13.8594905 , 15.16756761, 19.85201746,
#         9.42355809, 10.89886673,  6.8686854 , 22.17249844,  8.28630176,
#        10.51526495, 15.94386799,  8.56295639, 19.50007622, 12.23170893,
#        14.02894706, 11.53741957, 21.16817697,  9.97745977, 19.62580755,
#         9.69138443, 18.80254043, 19.44424855,  9.13374846, 10.44024332,
#         9.94172715, 15.45612484, 23.39733303, 12.34976436, 10.0366976 ,
#        18.63487018, 10.43699531, 16.4845852 , 18.40262901, 15.61577398,
#         5.52635671, 15.64624055, 10.33199905, 10.68489584, 12.69039858,
#        14.46828091, 13.85826838, 15.16633129, 17.38031794, 11.22263016,
#        14.83241118, 10.98742632, 13.60954124, 17.54348478, 18.05497517,
#         7.66571311, 14.69404283,  7.83773776, 12.1860612 , 13.95879341,
#        24.8961722 , 20.08034682, 12.49741579, 16.26810648, 12.6120828 ,
#        10.80609079, 14.21308301,  6.91724455, 24.43651853, 18.7387533 ,
#        20.83838281, 10.02181351, 17.19716031, 18.72439957,  6.36033186,
#        12.53672152,  8.61954913,  4.86386693, 18.46540316, 16.52823126,
#         5.66241857,  8.39634805, 12.95016055, 24.04652959, 15.33143648])

# %%
df['Predict'] = pred
df
# Out:
#         TV  radio  newspaper  sales    Predict
# 0    230.1   37.8       69.2   22.1  20.864165
# 1     44.5   39.3       45.1   10.4  12.611781
# 2     17.2   45.9       69.3    9.3  12.692306
# 3    151.5   41.3       58.5   18.5  17.891932
# 4    180.8   10.8       58.4   12.9  13.632878
# 5      8.7   48.9       75.0    7.2  12.882197
# 6     57.5   32.8       23.5   11.8  11.912769
# 7    120.2   19.6       11.6   13.2  12.284451
# 8      8.6    2.1        1.0    4.8   3.968790
# 9    199.8    2.6       21.2   10.6  12.823893
# 10    66.1    5.8       24.2    8.6   7.359669
# 11   214.7   24.0        4.0   17.4  17.342197
# 12    23.8   35.1       65.9    9.2  10.997719
# 13    97.5    7.6        7.2    9.7   9.036577
# 14   204.1   32.9       46.0   19.0  18.682152
# 15   195.4   47.7       52.9   22.4  21.030137
# 16    67.8   36.6      114.0   12.5  13.486064
# 17   281.4   39.6       55.8   24.4  23.459960
# 18    69.2   20.5       18.3   11.3  10.166545
# 19   147.3   23.9       19.1   14.6  14.335314
# 20   218.4   27.7       53.4   18.0  18.411634
# 21   237.4    5.1       23.5   12.5  14.997677
# 22    13.2   15.9       49.6    5.6   6.925717
# 23   228.3   16.9       26.2   15.5  16.758902
# 24    62.3   12.6       18.3    9.7   8.406332
# 25   262.9    3.5       19.5   12.0  15.843009
# 26   142.9   29.3       12.6   15.0  15.095569
# 27   240.1   16.7       22.9   15.9  17.242509
# 28   248.8   27.1       22.9   18.9  19.542356
# 29    70.6   16.0       40.8   10.5   9.507584
# ..     ...    ...        ...    ...        ...
# 170   50.0   11.6       18.4    8.4   7.665713
# 171  164.5   20.9       47.4   14.5  14.694043
# 172   19.6   20.1       17.0    7.6   7.837738
# 173  168.4    7.1       12.8   11.7  12.186061
# 174  222.4    3.4       13.1   11.5  13.958793
# 175  276.9   48.9       41.8   27.0  24.896172
# 176  248.4   30.2       20.3   20.2  20.080347
# 177  170.2    7.8       35.2   11.7  12.497416
# 178  276.7    2.3       23.7   11.8  16.268106
# 179  165.6   10.0       17.6   12.6  12.612083
# 180  156.6    2.6        8.3   10.5  10.806091
# 181  218.5    5.4       27.4   12.2  14.213083
# 182   56.2    5.7       29.7    8.7   6.917245
# 183  287.6   43.0       71.8   26.2  24.436519
# 184  253.8   21.3       30.0   17.6  18.738753
# 185  205.0   45.1       19.6   22.6  20.838383
# 186  139.5    2.1       26.6   10.3  10.021814
# 187  191.1   28.7       18.2   17.3  17.197160
# 188  286.0   13.9        3.7   15.9  18.724400
# 189   18.7   12.1       23.4    6.7   6.360332
# 190   39.5   41.1        5.8   10.8  12.536722
# 191   75.5   10.8        6.0    9.9   8.619549
# 192   17.2    4.1       31.6    5.9   4.863867
# 193  166.8   42.0        3.6   19.6  18.465403
# 194  149.7   35.6        6.0   17.3  16.528231
# 195   38.2    3.7       13.8    7.6   5.662419
# 196   94.2    4.9        8.1    9.7   8.396348
# 197  177.0    9.3        6.4   12.8  12.950161
# 198  283.6   42.0       66.2   25.5  24.046530
# 199  232.1    8.6        8.7   13.4  15.331436
#
# [200 rows x 5 columns]

# %%
df.plot(y=['sales', 'Predict'], figsize=(15,10), linewidth=5)

# %% [markdown]
# #
# #
# #
# #
# #
# #
# # < 예제 2 >
# # Logistic Regression
# #
# #

# %% [markdown]
# "diabetes.csv" 파일
#
# 당뇨병이 있는지 없는지 알아보자!
#
# < Columns >
# - Pregnancies : Number of times pregnant
# - Glucose : Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# - BloodPressure : Diastolic blood pressure (mm Hg)
# - SkinThickness : Triceps skin fold thickness (mm)
# - Insulin : 2-Hour serum insulin (mu U/ml)
# - BMI : Body mass index (weight in kg/(height in m)^2)
# - DiabetesPedigreeFunction : Diabetes pedigree function
# - Age : Age (years)

# %%
#import pandas
#아래에 코드 작성
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# load dataset
#아래에 코드 작성

df = pd.read_csv('data/diabetes.csv')

# %% [markdown]
# 데이터 head()로 확인

# %%
#아래에 코드 작성
df.head()
# sns.countplot(x='Outcome', data=df)
# plt.show()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# < Selecting Feature >

# %% [markdown]
# Outcome에 해당하는 열의 데이터만 y에 넣어주고 ( y는 target variable임. )
#
# 나머지 열 이름은 feature_cols 변수에 할당해서 x에 넣어주기  (x는 features임.)

# %%
#split dataset in features and target variable
#아래에 코드 작성
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

Y= df['Outcome']
X= df.iloc[:.2:6]
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
# 5      0
# 6      1
# 7      0
# 8      1
# 9      1
# 10     0
# 11     1
# 12     0
# 13     1
# 14     1
# 15     1
# 16     1
# 17     1
# 18     0
# 19     1
# 20     0
# 21     0
# 22     1
# 23     1
# 24     1
# 25     1
# 26     1
# 27     0
# 28     0
# 29     0
#       ..
# 738    0
# 739    1
# 740    1
# 741    0
# 742    0
# 743    1
# 744    0
# 745    0
# 746    1
# 747    0
# 748    1
# 749    1
# 750    1
# 751    0
# 752    0
# 753    1
# 754    1
# 755    1
# 756    0
# 757    1
# 758    0
# 759    1
# 760    0
# 761    1
# 762    0
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# x와 y를 training 과 testing sets으로 나누기 (size = 0.25, random_state = 0) 조건 설정!

# %%
# split X and y into training and testing sets

from sklearn.model_selection import train_test_split
#아래에 코드 작성

# %% [markdown]
# 로지스틱 회귀분석을 적용

# %%
# import the class
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression(solver= 'liblinear')

# fit the model with data
#아래에 코드 작성

# %% [markdown]
# ## .score() 로 확인!
# score()안에는 (test samples, true labels for x) 형태가 들어가야 함.

# %%
#아래에 코드 작성
